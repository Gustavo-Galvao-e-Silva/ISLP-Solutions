# %% [markdown]
# # ISLP – Chapter 2, Question 10
#
# **Dataset:** Boston
#
# **Objective:** Explore the structure, summary statistics, and relationships among predictors in the Boston housing dataset, with particular emphasis on crime rate, housing characteristics, and socioeconomic variables.

# %%
# Importing libraries and loading dataframe
import pandas as pd
import ISLP

df = ISLP.load_data("Boston").drop

# %% [markdown]
# # Solution - (a)
# We have effectively loaded the **Boston** housing dataset into the df variable.
#
#
# Note: more information about this dataset can be found in the [ISLP Boston housing dataset documentation](https://islp.readthedocs.io/en/latest/datasets/Boston.html).

# %%
# Problem (a) code

# Show loaded dataframe
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %% [markdown]
# # Solution - (b)
# By outputting the shape of the df with .shape, we can find the number of columns and rows, which is **506 rows** by **13 columns**. The columns represent the variables we have measured, while the rows are the observations made. As found in the dataset documentation, each variable means:
# * **crim:** per capita crime rate by town
# * **zn:** proportion of residential land zoned for lots over 25,000 sq.ft
# * **indus:** proportion of non-retail business acres per town
# * **chas:** Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# * **nox:** nitrogen oxides concentration (parts per 10 million)
# * **rm:** average number of rooms per dwelling
# * **age:** proportion of owner-occupied units built prior to 1940
# * **dis:** weighted mean of distances to five Boston employment centers
# * **rad:** index of accessibility to radial highways
# * **tax:** full-value property-tax rate per 10,000 dollars
# * **ptratio:** pupil-teacher ratio by town
# * **lstat:** lower status of the population (percent)
# * **medv:** median value of owner-occupied homes in 1000s of dollars
#
# Note on chas: this is a qualitative variable, but can still be used in plotting and EDA as it is encoded using integers

# %%
# Problem (b) code

# Find shape of dataframe
shape_tuple = df.shape

# Build and display dataframe with shape information
shape_df = pd.DataFrame([shape_tuple], columns=["Row", "Column"]).T.rename(columns={0: "Number"})
shape_df
# Out:
#         Number
# Row        506
# Column      13

# %% [markdown]
# # Solution - (c)
# To create pairwise scatter plots in this dataset, we can run Pandas's plotting .scatter_matrix() builtin and analyze the relationships between two given quantities, which yields the 13 by 13 matrix seen below.
#
# We see a few correlations

# %%
# Problem (c) code

# Display the pairwise scatter plots of all quantities against all other possible quantities
pd.plotting.scatter_matrix(df, figsize=(15, 15))
# Out:
# array([[<Axes: xlabel='crim', ylabel='crim'>,
#         <Axes: xlabel='zn', ylabel='crim'>,
#         <Axes: xlabel='indus', ylabel='crim'>,
#         <Axes: xlabel='chas', ylabel='crim'>,
#         <Axes: xlabel='nox', ylabel='crim'>,
#         <Axes: xlabel='rm', ylabel='crim'>,
#         <Axes: xlabel='age', ylabel='crim'>,
#         <Axes: xlabel='dis', ylabel='crim'>,
#         <Axes: xlabel='rad', ylabel='crim'>,
#         <Axes: xlabel='tax', ylabel='crim'>,
#         <Axes: xlabel='ptratio', ylabel='crim'>,
#         <Axes: xlabel='lstat', ylabel='crim'>,
#         <Axes: xlabel='medv', ylabel='crim'>],
#        [<Axes: xlabel='crim', ylabel='zn'>,
#         <Axes: xlabel='zn', ylabel='zn'>,
#         <Axes: xlabel='indus', ylabel='zn'>,
#         <Axes: xlabel='chas', ylabel='zn'>,
#         <Axes: xlabel='nox', ylabel='zn'>,
#         <Axes: xlabel='rm', ylabel='zn'>,
#         <Axes: xlabel='age', ylabel='zn'>,
#         <Axes: xlabel='dis', ylabel='zn'>,
# ...
